# %%
a=[12,56,89,100.6,"gitam"]
print(a)
print(type(a))
# Out:
# [12, 56, 89, 100.6, 'gitam']
# <class 'list'>

# %%
b=[34,78,19,100,56,34]
for ele in b:
  print(ele, end=" ")
print()
for i in range(len(b)):
  print(b[i],end=" ")
print()
i=0
while(i<len(b)):
  print(b[i],end=" ")
  i=i+1
# Out:
# 34 78 19 100 56 34
# 34 78 19 100 56 34
# 34 78 19 100 56 34

# %%
print(b[5])
# Out:
# 34

# %%
b
# Out:
# [34, 78, 19, 100, 56, 34]

# %%
print(b[-1])
# Out:
# 34

# %%
b[5]=100
b
# Out:
# [34, 78, 19, 100, 56, 100]

# %%
a
del a[0]
a
del a
a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-facdf7b6b9b9> in <module>()
#       3 a
#       4 del a
# ----> 5 a
#
# NameError: name 'a' is not defined

# %%
b
# Out:
# [34, 78, 19, 100, 56, 100]

# %%
print(b)
b.append(100)
b
# Out:
# [34, 78, 19, 100, 56, 100]
# [34, 78, 19, 100, 56, 100, 100]

# %%
print(b)
b.insert(0,1000)
b
# Out:
# [100, 34, 78, 19, 100, 56, 100, 100]
# [1000, 100, 34, 78, 19, 100, 56, 100, 100]

# %%
 b.pop(3)
 b
# Out:
# [1000, 100, 34, 19, 100, 56, 100, 100]

# %%
b.remove(1000)
b
# Out:
# [100, 34, 19, 100, 56, 100, 100]

# %%
b.reverse()
b
# Out:
# [100, 100, 56, 100, 19, 34, 100]

# %%
b.index(56)
# Out:
# 2

# %%
b.sort()
b.reverse()
b
# Out:
# [100, 100, 100, 100, 56, 34, 19]

# %%
max(b)
# Out:
# 100

# %%
min(b)
# Out:
# 19

# %%
sum(b)
# Out:
# 509

# %%
b
# Out:
# [100, 100, 100, 100, 56, 34, 19]

# %%
b.clear()
b
# Out:
# []

# %%
c=[]
n=int(input("enter the size"))
for i in range(n):
  c.append(int(input("enter the element")))
for ele in c:
  print(ele,end=" ")
# Out:
# enter the size3
# enter the element1
# enter the element2
# enter the element3
# 1 2 3
